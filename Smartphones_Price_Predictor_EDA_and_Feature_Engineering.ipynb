# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the dataset
df = pd.read_csv('processed_smartphones.csv')

# %% [markdown]
# ## Understanding the Data :

# %%
df.head()
# Out:
#       brand processor_name  processor_cores  processor_speed       os  ram  \
# 0   OnePlus     Snapdragon              8.0              3.2  Android   12
# 1   OnePlus     Snapdragon              8.0              2.2  Android    6
# 2   Samsung         Exynos              8.0              2.4  Android    4
# 3  Motorola     Snapdragon              8.0              2.2  Android    6
# 4    Realme      Dimensity              8.0              2.6  Android    6
#
#    is_ram_gb  storage  is_storage_gb  battery_capacity  ...  is_Vo5G  wifi  \
# 0          1      256              1              5000  ...        0     1
# 1          1      128              1              5000  ...        0     1
# 2          1       64              1              5000  ...        0     1
# 3          1      128              1              5000  ...        0     1
# 4          1      128              1              5000  ...        0     1
#
#    ngc  irblaster  display_size  display_height  display_width  rear_camera  \
# 0    1          0          6.70          3216.0         1440.0         50.0
# 1    0          0          6.59          2412.0         1080.0         64.0
# 2    0          0          6.60          2408.0         1080.0         50.0
# 3    0          0          6.55          2400.0         1080.0         50.0
# 4    0          0          6.70          2412.0         1080.0        108.0
#
#    front_camera  price
# 0          16.0  54999
# 1          16.0  19989
# 2          13.0  16499
# 3          16.0  14999
# 4          16.0  24999
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (1014, 23)

# %%
# missing values percentage
df.isnull().sum()
# Out:
# brand               0
# processor_name      0
# processor_cores     0
# processor_speed     0
# os                  0
# ram                 0
# is_ram_gb           0
# storage             0
# is_storage_gb       0
# battery_capacity    0
# DualSim             0
# Volte               0
# is_5G               0
# is_Vo5G             0
# wifi                0
# ngc                 0
# irblaster           0
# display_size        0
# display_height      0
# display_width       0
# rear_camera         0
# front_camera        0
# price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
df.head()
# Out:
#       brand processor_name  processor_cores  processor_speed       os  ram  \
# 0   OnePlus     Snapdragon              8.0              3.2  Android   12
# 1   OnePlus     Snapdragon              8.0              2.2  Android    6
# 2   Samsung         Exynos              8.0              2.4  Android    4
# 3  Motorola     Snapdragon              8.0              2.2  Android    6
# 4    Realme      Dimensity              8.0              2.6  Android    6
#
#    is_ram_gb  storage  is_storage_gb  battery_capacity  ...  is_Vo5G  wifi  \
# 0          1      256              1              5000  ...        0     1
# 1          1      128              1              5000  ...        0     1
# 2          1       64              1              5000  ...        0     1
# 3          1      128              1              5000  ...        0     1
# 4          1      128              1              5000  ...        0     1
#
#    ngc  irblaster  display_size  display_height  display_width  rear_camera  \
# 0    1          0          6.70          3216.0         1440.0         50.0
# 1    0          0          6.59          2412.0         1080.0         64.0
# 2    0          0          6.60          2408.0         1080.0         50.0
# 3    0          0          6.55          2400.0         1080.0         50.0
# 4    0          0          6.70          2412.0         1080.0        108.0
#
#    front_camera  price
# 0          16.0  54999
# 1          16.0  19989
# 2          13.0  16499
# 3          16.0  14999
# 4          16.0  24999
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1011 entries, 0 to 1010
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             1011 non-null   object
#  1   processor_name    1011 non-null   object
#  2   processor_cores   1011 non-null   float64
#  3   processor_speed   1011 non-null   float64
#  4   os                1011 non-null   object
#  5   ram               1011 non-null   int64
#  6   is_ram_gb         1011 non-null   int64
#  7   storage           1011 non-null   int64
#  8   is_storage_gb     1011 non-null   int64
#  9   battery_capacity  1011 non-null   int64
#  10  DualSim           1011 non-null   int64
#  11  Volte             1011 non-null   int64
#  12  is_5G             1011 non-null   int64
#  13  is_Vo5G           1011 non-null   int64
#  14  wifi              1011 non-null   int64
#  15  ngc               1011 non-null   int64
#  16  irblaster         1011 non-null   int64
#  17  display_size      1011 non-null   float64
#  18  display_height    1011 non-null   float64
#  19  display_width     1011 non-null   float64
#  20  rear_camera       1011 non-null   float64
#  21  front_camera      1011 non-null   float64
#  22  price             1011 non-null   int64
# dtypes: float64(7), int64(13), object(3)
# memory usage: 181.8+ KB

# %% [markdown]
# ## Exploratory Data Analysis :

# %% [markdown]
# ### 1. Brand :
